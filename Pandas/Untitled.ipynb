# %%
import pandas as pd
import numpy as np

# %%
rides = pd.read_csv("ncr_ride_bookings.csv", parse_dates = ["Date"])

# %%
rides.sample(2)
# Out:
#              Date      Time    Booking ID         Booking Status  \
# 134033 2024-06-03  17:22:44  "CNR1554852"  Cancelled by Customer
# 16442  2024-04-30  09:33:12  "CNR2952060"             Incomplete
#
#          Customer ID   Vehicle Type Pickup Location Drop Location  Avg VTAT  \
# 134033  "CID9377413"        Go Mini    Keshav Puram   Udyog Vihar       5.4
# 16442   "CID2569213"  Premier Sedan           Okhla    Moti Nagar       9.4
#
#         Avg CTAT  ...             Reason for cancelling by Customer  \
# 134033       NaN  ...  Driver is not moving towards pickup location
# 16442       16.2  ...                                           NaN
#
#        Cancelled Rides by Driver  Driver Cancellation Reason Incomplete Rides  \
# 134033                       NaN                         NaN              NaN
# 16442                        NaN                         NaN              1.0
#
#         Incomplete Rides Reason Booking Value  Ride Distance  Driver Ratings  \
# 134033                      NaN           NaN            NaN             NaN
# 16442               Other Issue         421.0          10.85             NaN
#
#         Customer Rating  Payment Method
# 134033              NaN             NaN
# 16442               NaN             UPI
#
# [2 rows x 21 columns]

# %% [markdown]
# #### 1)Convert Date and Time to datetime

# %%
rides["Date"].dtype # we had converted the date col to date col to datetime dtype at time of reading csv file
# Out:
# dtype('<M8[ns]')

# %%
rides["Time"] = pd.to_datetime(rides["Time"], errors = "coerce", format = "%H:%M:%S") 
## pandas add dummy date to time 1900-01-01 hh:mm:ss
# if we don't want this dummy date then do this:
# pd.to_datetime(rides["Time"], errors = "coerce", format = "%H:%M:%S").dt.time .
# However, this will be python datetime obj and will be of "object type".

# %%
rides["Time"].dtype
# Out:
# dtype('<M8[ns]')

# %%
rides.sample()
# Out:
#              Date                Time    Booking ID Booking Status  \
# 127879 2024-06-04 1900-01-01 10:19:13  "CNR2480524"      Completed
#
#          Customer ID Vehicle Type Pickup Location Drop Location  Avg VTAT  \
# 127879  "CID7897530"         Auto      Chhatarpur       Jhilmil       5.5
#
#         Avg CTAT  ...  Reason for cancelling by Customer  \
# 127879      23.4  ...                                NaN
#
#        Cancelled Rides by Driver  Driver Cancellation Reason Incomplete Rides  \
# 127879                       NaN                         NaN              NaN
#
#         Incomplete Rides Reason Booking Value  Ride Distance  Driver Ratings  \
# 127879                      NaN         679.0          19.41             4.4
#
#         Customer Rating  Payment Method
# 127879              3.6     Uber Wallet
#
# [1 rows x 21 columns]

# %% [markdown]
# #### 2)Combine Date and Time into a single datetime column
# ##### method 1:
#
# Since our "Date" and "Time" are both datetime, we can’t directly add them.
# But if we convert each to string in the right format using .dt.strftime(),
# then concatenate, then parse back → we get a clean datetime column:
#
# ##### method 2:
# we could also combine these two cols durind reading the file time only using parde_date = [" "] and get datetime type col
#
# ##### some situation:
#
# if:
#
# "Date" is datetime64[ns]
#
# "Time" (after pd.to_datetime(rides["Time"], errors = "coerce", format = "%H:%M:%S").dt.time .) is Python datetime.time objects (object dtype)
#
# Pandas can’t directly add those two.
#
# solution:
#
# rides["Date Time"] = pd.to_datetime( rides["Date"].astype(str) + " " + rides["Time"].astype(str),errors="coerce")

# %%
#method 1:

rides["Date Time"] = pd.to_datetime(rides["Date"].dt.strftime("%Y-%m-%d")+" "+ rides["Time"].dt.strftime("%H-%M-%S"), format = "%Y-%m-%d %H-%M-%S",errors = "coerce")

# %%
rides["Date Time"].dtype
# Out:
# dtype('<M8[ns]')

# %%
rides.sample(3)
# Out:
#              Date                Time    Booking ID   Booking Status  \
# 74111  2024-08-14 1900-01-01 12:00:48  "CNR6006614"        Completed
# 44495  2024-09-14 1900-01-01 16:27:08  "CNR9249883"  No Driver Found
# 131253 2024-05-21 1900-01-01 21:12:11  "CNR2285776"       Incomplete
#
#          Customer ID Vehicle Type Pickup Location Drop Location  Avg VTAT  \
# 74111   "CID6708761"     Go Sedan  Sarojini Nagar        Rohini      14.2
# 44495   "CID8982220"     Go Sedan    Udyog Bhawan  Shivaji Park       NaN
# 131253  "CID7501409"     Go Sedan         Azadpur       Bhiwadi       4.9
#
#         Avg CTAT  ...  Cancelled Rides by Driver Driver Cancellation Reason  \
# 74111       35.0  ...                        NaN                        NaN
# 44495        NaN  ...                        NaN                        NaN
# 131253      20.2  ...                        NaN                        NaN
#
#         Incomplete Rides Incomplete Rides Reason  Booking Value Ride Distance  \
# 74111                NaN                     NaN          801.0         25.68
# 44495                NaN                     NaN            NaN           NaN
# 131253               1.0         Customer Demand          325.0         18.87
#
#         Driver Ratings  Customer Rating  Payment Method           Date Time
# 74111              4.5              4.6             UPI 2024-08-14 12:00:48
# 44495              NaN              NaN             NaN 2024-09-14 16:27:08
# 131253             NaN              NaN             UPI 2024-05-21 21:12:11
#
# [3 rows x 22 columns]

# %%
#method 2:
#will be deprecated in future . so use above method
rides2 = pd.read_csv("ncr_ride_bookings.csv", parse_dates = {"DateTime" : ["Date","Time"]})
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11764\1027789386.py:3: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   rides2 = pd.read_csv("ncr_ride_bookings.csv", parse_dates = {"DateTime" : ["Date","Time"]})

# %%
rides2
# Out:
#                   DateTime    Booking ID   Booking Status   Customer ID  \
# 0      2024-03-23 12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1      2024-11-29 18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2      2024-08-23 08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3      2024-10-21 17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4      2024-09-16 22:08:00  "CNR1950162"        Completed  "CID9933542"
# ...                    ...           ...              ...           ...
# 149995 2024-11-11 19:34:01  "CNR6500631"        Completed  "CID4337371"
# 149996 2024-11-24 15:55:09  "CNR2468611"        Completed  "CID2325623"
# 149997 2024-09-18 10:55:15  "CNR6358306"        Completed  "CID9925486"
# 149998 2024-10-05 07:53:34  "CNR3030099"        Completed  "CID9415487"
# 149999 2024-03-10 15:38:03  "CNR3447390"        Completed  "CID4108667"
#
#          Vehicle Type         Pickup Location      Drop Location  Avg VTAT  \
# 0               eBike             Palam Vihar            Jhilmil       NaN
# 1            Go Sedan           Shastri Nagar  Gurgaon Sector 56       4.9
# 2                Auto                 Khandsa      Malviya Nagar      13.4
# 3       Premier Sedan     Central Secretariat           Inderlok      13.1
# 4                Bike        Ghitorni Village        Khan Market       5.3
# ...               ...                     ...                ...       ...
# 149995        Go Mini                 MG Road           Ghitorni      10.2
# 149996        Go Mini        Golf Course Road         Akshardham       5.1
# 149997       Go Sedan  Satguru Ram Singh Marg           Jor Bagh       2.7
# 149998           Auto               Ghaziabad         Saidulajab       6.9
# 149999  Premier Sedan         Ashok Park Main  Gurgaon Sector 29       3.5
#
#         Avg CTAT  Cancelled Rides by Customer  \
# 0            NaN                          NaN
# 1           14.0                          NaN
# 2           25.8                          NaN
# 3           28.5                          NaN
# 4           19.6                          NaN
# ...          ...                          ...
# 149995      44.4                          NaN
# 149996      30.8                          NaN
# 149997      23.4                          NaN
# 149998      39.6                          NaN
# 149999      33.7                          NaN
#
#        Reason for cancelling by Customer  Cancelled Rides by Driver  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 3                                    NaN                        NaN
# 4                                    NaN                        NaN
# ...                                  ...                        ...
# 149995                               NaN                        NaN
# 149996                               NaN                        NaN
# 149997                               NaN                        NaN
# 149998                               NaN                        NaN
# 149999                               NaN                        NaN
#
#        Driver Cancellation Reason  Incomplete Rides Incomplete Rides Reason  \
# 0                             NaN               NaN                     NaN
# 1                             NaN               1.0       Vehicle Breakdown
# 2                             NaN               NaN                     NaN
# 3                             NaN               NaN                     NaN
# 4                             NaN               NaN                     NaN
# ...                           ...               ...                     ...
# 149995                        NaN               NaN                     NaN
# 149996                        NaN               NaN                     NaN
# 149997                        NaN               NaN                     NaN
# 149998                        NaN               NaN                     NaN
# 149999                        NaN               NaN                     NaN
#
#         Booking Value  Ride Distance  Driver Ratings  Customer Rating  \
# 0                 NaN            NaN             NaN              NaN
# 1               237.0           5.73             NaN              NaN
# 2               627.0          13.58             4.9              4.9
# 3               416.0          34.02             4.6              5.0
# 4               737.0          48.21             4.1              4.3
# ...               ...            ...             ...              ...
# 149995          475.0          40.08             3.7              4.1
# 149996         1093.0          21.31             4.8              5.0
# 149997          852.0          15.93             3.9              4.4
# 149998          333.0          45.54             4.1              3.7
# 149999          806.0          21.19             4.6              4.9
#
#        Payment Method
# 0                 NaN
# 1                 UPI
# 2          Debit Card
# 3                 UPI
# 4                 UPI
# ...               ...
# 149995    Uber Wallet
# 149996            UPI
# 149997           Cash
# 149998            UPI
# 149999    Credit Card
#
# [150000 rows x 20 columns]

# %% [markdown]
# #### 3)Extract temporal features

# %%
rides["Date Time"].dt.year
# Out:
# 0         2024
# 1         2024
# 2         2024
# 3         2024
# 4         2024
#           ...
# 149995    2024
# 149996    2024
# 149997    2024
# 149998    2024
# 149999    2024
# Name: Date Time, Length: 150000, dtype: int32

# %%
rides["Date Time"].dt.month
# Out:
# 0          3
# 1         11
# 2          8
# 3         10
# 4          9
#           ..
# 149995    11
# 149996    11
# 149997     9
# 149998    10
# 149999     3
# Name: Date Time, Length: 150000, dtype: int32

# %%
rides["Date Time"].dt.day
# Out:
# 0         23
# 1         29
# 2         23
# 3         21
# 4         16
#           ..
# 149995    11
# 149996    24
# 149997    18
# 149998     5
# 149999    10
# Name: Date Time, Length: 150000, dtype: int32

# %%
rides["Date Time"].dt.day_name()
# Out:
# 0          Saturday
# 1            Friday
# 2            Friday
# 3            Monday
# 4            Monday
#             ...
# 149995       Monday
# 149996       Sunday
# 149997    Wednesday
# 149998     Saturday
# 149999       Sunday
# Name: Date Time, Length: 150000, dtype: object

# %%
rides["Date Time"].dt.month_name()
# Out:
# 0             March
# 1          November
# 2            August
# 3           October
# 4         September
#             ...
# 149995     November
# 149996     November
# 149997    September
# 149998      October
# 149999        March
# Name: Date Time, Length: 150000, dtype: object

# %%
rides["Date Time"].dt.hour
# Out:
# 0         12
# 1         18
# 2          8
# 3         17
# 4         22
#           ..
# 149995    19
# 149996    15
# 149997    10
# 149998     7
# 149999    15
# Name: Date Time, Length: 150000, dtype: int32

# %%
rides["Date Time"].dt.minute
# Out:
# 0         29
# 1          1
# 2         56
# 3         17
# 4          8
#           ..
# 149995    34
# 149996    55
# 149997    55
# 149998    53
# 149999    38
# Name: Date Time, Length: 150000, dtype: int32

# %%
rides["Date Time"].dt.second
# Out:
# 0         38
# 1         39
# 2         10
# 3         25
# 4          0
#           ..
# 149995     1
# 149996     9
# 149997    15
# 149998    34
# 149999     3
# Name: Date Time, Length: 150000, dtype: int32

# %%
rides["Date Time"].dt.day_of_week
# Out:
# 0         5
# 1         4
# 2         4
# 3         0
# 4         0
#          ..
# 149995    0
# 149996    6
# 149997    2
# 149998    5
# 149999    6
# Name: Date Time, Length: 150000, dtype: int32

# %% [markdown]
# #### # 4)Create binary flags from cancellation/incomplete columns

# %%
pd.set_option("display.max_column",None)
rides2.sample(3)
# Out:
#                   DateTime    Booking ID       Booking Status   Customer ID  \
# 67011  2024-04-02 21:28:16  "CNR8423108"  Cancelled by Driver  "CID5606611"
# 115882 2024-08-06 11:17:17  "CNR3440856"  Cancelled by Driver  "CID6890475"
# 128462 2024-10-10 21:33:33  "CNR5018901"            Completed  "CID8540871"
#
#        Vehicle Type Pickup Location Drop Location  Avg VTAT  Avg CTAT  \
# 67011          Bike    Lajpat Nagar        Mundka       7.8       NaN
# 115882     Go Sedan      Sohna Road   Udyog Vihar       4.1       NaN
# 128462      Go Mini     Uttam Nagar    New Colony      14.9      24.2
#
#         Cancelled Rides by Customer Reason for cancelling by Customer  \
# 67011                           NaN                               NaN
# 115882                          NaN                               NaN
# 128462                          NaN                               NaN
#
#         Cancelled Rides by Driver      Driver Cancellation Reason  \
# 67011                         1.0   Personal & Car related issues
# 115882                        1.0  The customer was coughing/sick
# 128462                        NaN                             NaN
#
#         Incomplete Rides Incomplete Rides Reason  Booking Value  \
# 67011                NaN                     NaN            NaN
# 115882               NaN                     NaN            NaN
# 128462               NaN                     NaN          263.0
#
#         Ride Distance  Driver Ratings  Customer Rating Payment Method
# 67011             NaN             NaN              NaN            NaN
# 115882            NaN             NaN              NaN            NaN
# 128462          43.66             3.4              4.1            UPI

# %%
rides2["cancellation_flag"] = np.where((rides2["Cancelled Rides by Customer"].notna() ) | (rides2["Cancelled Rides by Driver"].notna() ),1,0)

# %%
rides2["cancellation_flag"].value_counts()  ## 1: ride cancelled, 0 : not cancelled
# Out:
# cancellation_flag
# 0    112500
# 1     37500
# Name: count, dtype: int64

# %%
rides2["customer_cancellation_flag"] = np.where(rides2["Cancelled Rides by Customer"].notna(),1,0)

# %%
rides2["customer_cancellation_flag"].value_counts()
# Out:
# customer_cancellation_flag
# 0    139500
# 1     10500
# Name: count, dtype: int64

# %%
rides2["driver_cancellation_flag"] = np.where(rides2["Cancelled Rides by Driver"].notna(),1,0)

# %%
rides2["driver_cancellation_flag"].value_counts()
# Out:
# driver_cancellation_flag
# 0    123000
# 1     27000
# Name: count, dtype: int64

# %%
rides2["incomplete_flag"] = np.where(rides2["Incomplete Rides"].notna(), 1,0)

# %%
rides2["incomplete_flag"].value_counts()
# Out:
# incomplete_flag
# 0    141000
# 1      9000
# Name: count, dtype: int64

# %% [markdown]
# #### 5)Create a flag for missing ratings and booking values

# %%
rides2.sample(3)
# Out:
#                   DateTime    Booking ID Booking Status   Customer ID  \
# 121551 2024-07-30 08:06:12  "CNR4931218"      Completed  "CID9014414"
# 20075  2024-11-02 01:04:01  "CNR7982564"      Completed  "CID7018672"
# 87141  2024-01-23 14:39:00  "CNR1715877"      Completed  "CID7030947"
#
#          Vehicle Type Pickup Location Drop Location  Avg VTAT  Avg CTAT  \
# 121551  Premier Sedan        Vaishali       Sonipat      11.6      20.0
# 20075         Go Mini       IIT Delhi  Shivaji Park       9.9      35.8
# 87141         Go Mini    Udyog Bhawan  Punjabi Bagh      11.9      37.5
#
#         Cancelled Rides by Customer Reason for cancelling by Customer  \
# 121551                          NaN                               NaN
# 20075                           NaN                               NaN
# 87141                           NaN                               NaN
#
#         Cancelled Rides by Driver Driver Cancellation Reason  \
# 121551                        NaN                        NaN
# 20075                         NaN                        NaN
# 87141                         NaN                        NaN
#
#         Incomplete Rides Incomplete Rides Reason  Booking Value  \
# 121551               NaN                     NaN          667.0
# 20075                NaN                     NaN          397.0
# 87141                NaN                     NaN          944.0
#
#         Ride Distance  Driver Ratings  Customer Rating Payment Method  \
# 121551          30.29             4.3              4.9           Cash
# 20075           19.32             4.0              4.9           Cash
# 87141           26.36             3.9              4.6           Cash
#
#         cancellation_flag  customer_cancellation_flag  \
# 121551                  0                           0
# 20075                   0                           0
# 87141                   0                           0
#
#         driver_cancellation_flag  incomplete_flag
# 121551                         0                0
# 20075                          0                0
# 87141                          0                0

# %%
rides2["missing_ratings"] = np.where((rides2["Driver Ratings"].notna()) & (rides2["Customer Rating"].notna()),0,1)

# %%
rides2["driver_missing_ratings"]  = np.where(rides["Driver Ratings"].notna(),0,1)

# %%
rides2["customer_missing_ratings"]  = np.where(rides["Customer Rating"].notna(),0,1)

# %%
rides2.sample(3)
# Out:
#                   DateTime    Booking ID Booking Status   Customer ID  \
# 96184  2024-08-28 20:59:07  "CNR3444982"      Completed  "CID4348213"
# 140800 2024-01-20 20:04:29  "CNR7249560"      Completed  "CID6306563"
# 35559  2024-05-12 08:18:27  "CNR6377445"      Completed  "CID2215339"
#
#          Vehicle Type Pickup Location Drop Location  Avg VTAT  Avg CTAT  \
# 96184            Bike       Moolchand       Panipat       7.8      34.6
# 140800  Premier Sedan      Badshahpur    New Colony       9.5      35.2
# 35559            Auto        Inderlok       Azadpur       6.8      33.9
#
#         Cancelled Rides by Customer Reason for cancelling by Customer  \
# 96184                           NaN                               NaN
# 140800                          NaN                               NaN
# 35559                           NaN                               NaN
#
#         Cancelled Rides by Driver Driver Cancellation Reason  \
# 96184                         NaN                        NaN
# 140800                        NaN                        NaN
# 35559                         NaN                        NaN
#
#         Incomplete Rides Incomplete Rides Reason  Booking Value  \
# 96184                NaN                     NaN          865.0
# 140800               NaN                     NaN           92.0
# 35559                NaN                     NaN          941.0
#
#         Ride Distance  Driver Ratings  Customer Rating Payment Method  \
# 96184           22.13             4.4              4.6           Cash
# 140800          18.99             4.3              4.3           Cash
# 35559           16.82             4.2              4.7           Cash
#
#         cancellation_flag  customer_cancellation_flag  \
# 96184                   0                           0
# 140800                  0                           0
# 35559                   0                           0
#
#         driver_cancellation_flag  incomplete_flag  missing_ratings  \
# 96184                          0                0                0
# 140800                         0                0                0
# 35559                          0                0                0
#
#         driver_missing_ratings  customer_missing_ratings
# 96184                        0                         0
# 140800                       0                         0
# 35559                        0                         0

# %%
rides2["Booking Value"]  = np.where(rides["Booking Value"].notna(),0,1)

# %%
rides2["Booking Value"].value_counts()
# Out:
# Booking Value
# 0    102000
# 1     48000
# Name: count, dtype: int64

# %% [markdown]
# #### 6)Define Target for Customer Cancellation

# %%
# we have already created the target which is customer cancellation flg
rides2["customer_cancellation_flag"].value_counts()
# Out:
# customer_cancellation_flag
# 0    139500
# 1     10500
# Name: count, dtype: int64

# %% [markdown]
# #### 7)Cancellation Rate by Vehicle Type

# %%
# method 1
round((rides2.groupby("Vehicle Type")["cancellation_flag"].mean())*100,2).reset_index()
# Out:
#     Vehicle Type  cancellation_flag
# 0           Auto              24.92
# 1           Bike              25.10
# 2        Go Mini              24.92
# 3       Go Sedan              25.29
# 4  Premier Sedan              24.94
# 5        Uber XL              24.48
# 6          eBike              24.91

# %%
# method 2
round((rides2.groupby("Vehicle Type").agg(cancellation_rate = ("cancellation_flag" ,"mean")))*100,2)
# Out:
#                cancellation_rate
# Vehicle Type
# Auto                       24.92
# Bike                       25.10
# Go Mini                    24.92
# Go Sedan                   25.29
# Premier Sedan              24.94
# Uber XL                    24.48
# eBike                      24.91

# %% [markdown]
# ##### why use mean for cancellation rate:
# Suppose in the 10 AM group you have 5 rides:
#
# Sum of flags = 1+0+0+1+0 = 2
#
# Total rides = 5
#
# Cancellation rate = 2/5 = 0.4 (40%)
#
# Now check what mean gives:
#
# mean=(1+0+0+1+0)/5=0.4
#
# Same thing!

# %% [markdown]
# #### 8)Cancellation Rate by Hour

# %%
rides2.sample()
# Out:
#                   DateTime    Booking ID Booking Status   Customer ID  \
# 132395 2024-09-11 19:35:12  "CNR2406802"      Completed  "CID5242720"
#
#        Vehicle Type Pickup Location Drop Location  Avg VTAT  Avg CTAT  \
# 132395     Go Sedan          Ashram        Nawada       2.8      29.1
#
#         Cancelled Rides by Customer Reason for cancelling by Customer  \
# 132395                          NaN                               NaN
#
#         Cancelled Rides by Driver Driver Cancellation Reason  \
# 132395                        NaN                        NaN
#
#         Incomplete Rides Incomplete Rides Reason  Booking Value  \
# 132395               NaN                     NaN              0
#
#         Ride Distance  Driver Ratings  Customer Rating Payment Method  \
# 132395          43.76             4.9              4.8            UPI
#
#         cancellation_flag  customer_cancellation_flag  \
# 132395                  0                           0
#
#         driver_cancellation_flag  incomplete_flag  missing_ratings  \
# 132395                         0                0                0
#
#         driver_missing_ratings  customer_missing_ratings
# 132395                       0                         0

# %%
# rides2["hours"]=rides2["DateTime"].dt.hour

# %%
round((rides2.groupby(rides2["DateTime"].dt.hour).agg( cancellation_rate_by_hour = ("cancellation_flag" ,"mean")))*100,2)
# Out:
#           cancellation_rate_by_hour
# DateTime
# 0                             24.76
# 1                             25.29
# 2                             22.18
# 3                             25.67
# 4                             25.59
# 5                             26.42
# 6                             24.16
# 7                             25.36
# 8                             24.98
# 9                             24.91
# 10                            24.90
# 11                            24.05
# 12                            24.74
# 13                            25.25
# 14                            26.08
# 15                            25.68
# 16                            24.52
# 17                            24.89
# 18                            25.38
# 19                            25.53
# 20                            24.59
# 21                            23.98
# 22                            25.57
# 23                            25.42

# %% [markdown]
# #### 9)Cancellation Rate by Day of Week

# %%
days = ["Monday","Tuesday","Wednesday","Thursday","Friday", "Saturday","Sunday"]
cancellation_by_day = round((rides2.groupby(rides2["DateTime"].dt.day_name()).agg(cancellation_rate_day = ("cancellation_flag" ,"mean")))*100,2)
cancellation_by_day.reindex(days)
# Out:
#            cancellation_rate_day
# DateTime
# Monday                     25.65
# Tuesday                    25.19
# Wednesday                  24.82
# Thursday                   24.66
# Friday                     24.97
# Saturday                   24.73
# Sunday                     24.97

# %% [markdown]
# #### 10)Driver Rating vs Cancellation

# %%
round((rides2.groupby(rides2["Driver Ratings"]).agg(cancellation_rate = ("cancellation_flag" ,"mean")))*100,2)
# Out:
#                 cancellation_rate
# Driver Ratings
# 3.0                           0.0
# 3.1                           0.0
# 3.2                           0.0
# 3.3                           0.0
# 3.4                           0.0
# 3.5                           0.0
# 3.6                           0.0
# 3.7                           0.0
# 3.8                           0.0
# 3.9                           0.0
# 4.0                           0.0
# 4.1                           0.0
# 4.2                           0.0
# 4.3                           0.0
# 4.4                           0.0
# 4.5                           0.0
# 4.6                           0.0
# 4.7                           0.0
# 4.8                           0.0
# 4.9                           0.0
# 5.0                           0.0

# %%
# making bins of ratings
bins = [0,2,3,4,5]
labels = ["1-2","2-3","3-4","4-5"]
rides2["ratings"]=pd.cut(rides2["Driver Ratings"], bins = bins , labels = labels, include_lowest = True)

# %%
round((rides2.groupby(rides2["ratings"]).agg(cancellation_rate = ("cancellation_flag" ,"mean")))*100,2)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11764\3030147022.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   round((rides2.groupby(rides2["ratings"]).agg(cancellation_rate = ("cancellation_flag" ,"mean")))*100,2)
#          cancellation_rate
# ratings
# 1-2                    NaN
# 2-3                    0.0
# 3-4                    0.0
# 4-5                    0.0
